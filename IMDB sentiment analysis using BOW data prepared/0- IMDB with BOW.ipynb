# %%
import numpy as np
from keras.datasets import imdb

# %%
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 2s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  2,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  2,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}  # Create a dictionary
decoded_review = " ".join([reverse_word_index.get(i - 3, '?') for i in train_data[0]])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 1s 1us/step

# %%
decoded_review
# Out:
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
# Our vectorized labels
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# ### build network

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

model.compile(optimizer=optimizers.RMSprop(lr=0.001),
              loss=losses.binary_crossentropy,
              metrics=[metrics.binary_accuracy])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.

# %%
# split data
x_val=x_train[:10000]
partial_x_train=x_train[10000:]

y_val=y_train[:10000]

partial_y_val=y_train[10000:]

print (len(x_val))
print (len(y_val))
print (len(partial_x_train))
print (len(partial_y_val))
# Out:
# 10000
# 10000
# 15000
# 15000

# %%
history=model.fit(partial_x_train,partial_y_val,epochs=20,batch_size=512,validation_data=(x_val,y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 4s 70ms/step - loss: 0.5383 - binary_accuracy: 0.7712 - val_loss: 0.4173 - val_binary_accuracy: 0.8498
# Epoch 2/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.3332 - binary_accuracy: 0.8921 - val_loss: 0.3170 - val_binary_accuracy: 0.8810
# Epoch 3/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.2499 - binary_accuracy: 0.9167 - val_loss: 0.2846 - val_binary_accuracy: 0.8898
# Epoch 4/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.2019 - binary_accuracy: 0.9333 - val_loss: 0.2741 - val_binary_accuracy: 0.8894
# Epoch 5/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1656 - binary_accuracy: 0.9475 - val_loss: 0.2750 - val_binary_accuracy: 0.8876
# Epoch 6/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1413 - binary_accuracy: 0.9553 - val_loss: 0.3054 - val_binary_accuracy: 0.8777
# Epoch 7/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.1196 - binary_accuracy: 0.9631 - val_loss: 0.2992 - val_binary_accuracy: 0.8811
# Epoch 8/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1036 - binary_accuracy: 0.9683 - val_loss: 0.3189 - val_binary_accuracy: 0.8773
# Epoch 9/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0913 - binary_accuracy: 0.9737 - val_loss: 0.3318 - val_binary_accuracy: 0.8760
# Epoch 10/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0735 - binary_accuracy: 0.9809 - val_loss: 0.3548 - val_binary_accuracy: 0.8801
# Epoch 11/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.0668 - binary_accuracy: 0.9825 - val_loss: 0.3658 - val_binary_accuracy: 0.8799
# Epoch 12/20
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0533 - binary_accuracy: 0.9879 - val_loss: 0.3852 - val_binary_accuracy: 0.8802
# Epoch 13/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0473 - binary_accuracy: 0.9886 - val_loss: 0.4166 - val_binary_accuracy: 0.8766
# Epoch 14/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0405 - binary_accuracy: 0.9910 - val_loss: 0.4220 - val_binary_accuracy: 0.8758
# Epoch 15/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0323 - binary_accuracy: 0.9947 - val_loss: 0.4476 - val_binary_accuracy: 0.8733
# Epoch 16/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0259 - binary_accuracy: 0.9955 - val_loss: 0.4739 - val_binary_accuracy: 0.8752
# Epoch 17/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0226 - binary_accuracy: 0.9963 - val_loss: 0.4990 - val_binary_accuracy: 0.8724
# Epoch 18/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0191 - binary_accuracy: 0.9974 - val_loss: 0.5264 - val_binary_accuracy: 0.8693
# Epoch 19/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0158 - binary_accuracy: 0.9983 - val_loss: 0.5410 - val_binary_accuracy: 0.8719
# Epoch 20/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0161 - binary_accuracy: 0.9968 - val_loss: 0.5605 - val_binary_accuracy: 0.8719

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
import matplotlib.pyplot as plt

acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
## The model is suffer from overfitting
